# %% [markdown]
# **Importing Modules**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1- Read the Dataset**

# %%
data = pd.read_excel('/home/saf/Desktop/Datasets/iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **2- To Display The Columns of Dataset**

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# **3- To Display The Mean**

# %%
data['SL'].mean()
# Out:
# 5.843333333333334

# %%
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
data['PW'].mean()
# Out:
# 1.1986666666666668

# %% [markdown]
# **4- To Display Null Values**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# **OR**

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# **5- Visualization**

# %% [markdown]
# 1) Bar Plot(using matplotlib)

# %%
plt.figure(figsize=(8,6))
plt.bar(data['Classification'],data['PW'],color='maroon')
plt.title('Bar Graph')
plt.xlabel('Classification')
plt.ylabel('PW')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(data['Classification'],data['PL'],color='maroon')
plt.title('Bar Graph')
plt.xlabel('Classification')
plt.ylabel('PL')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(data['Classification'],data['SW'],color='maroon')
plt.title('Bar Graph')
plt.xlabel('Classification')
plt.ylabel('SW')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(data['Classification'],data['SL'],color='maroon')
plt.title('Bar Graph')
plt.xlabel('Classification')
plt.ylabel('SL')
plt.show()

# %% [markdown]
# 2) Box Plot(matplotlib)

# %%
plt.boxplot(data['PW'])
plt.show()

# %%
plt.boxplot(data['PL'])
plt.show()

# %%
plt.boxplot(data['SL'])
plt.show()

# %%
plt.boxplot(data['SW'])
plt.show()

# %%
plt.figure(figsize=(8,10))
data1=data.set_index('Classification')
plt.boxplot(data1);

# %% [markdown]
# Note:- Box plot using seaborn

# %%
sns.boxplot(x = data['Classification'],y = data['SW'])
plt.show()

# %%
sns.boxplot(x = data['Classification'],y = data['SL'])
plt.show()

# %%
sns.boxplot(x = data['Classification'],y = data['PW'])
plt.show()

# %%
sns.boxplot(x = data['Classification'],y = data['PL'])
plt.show()

# %% [markdown]
# 3) Scatter Diagram(matplotlib)

# %%
plt.scatter(data['Classification'],data['SL'])
plt.title('Scatter Diagram')
plt.xlabel('Classification')
plt.ylabel('SL')
plt.show()

# %% [markdown]
# Note :-Scatter diagram using seaborn

# %%
sns.scatterplot(x = data['Classification'],y = data['SW'])
plt.show()

# %%
sns.scatterplot(x = data['Classification'],y = data['SL'])
plt.show()

# %%
sns.scatterplot(x = data['Classification'],y = data['PW'])
plt.show()

# %%
sns.scatterplot(x = data['Classification'],y = data['PL'])
plt.show()
